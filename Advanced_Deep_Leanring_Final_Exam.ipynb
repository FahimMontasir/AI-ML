# %% [markdown]
# # NLP Exam
#  Notebook
#
# Fill in the blanks to complete each coding task. <br>
# Each question have 5 marks.

# %%
import sys
import subprocess

subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'gensim', 'nltk'])
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# Requirement already satisfied: gensim in ./.venv/lib/python3.13/site-packages (4.4.0)
# Requirement already satisfied: nltk in ./.venv/lib/python3.13/site-packages (3.9.4)
# Requirement already satisfied: numpy>=1.18.5 in ./.venv/lib/python3.13/site-packages (from gensim) (2.5.0)
# Requirement already satisfied: scipy>=1.7.0 in ./.venv/lib/python3.13/site-packages (from gensim) (1.18.0)
# Requirement already satisfied: smart_open>=1.8.1 in ./.venv/lib/python3.13/site-packages (from gensim) (8.0.0)
# Requirement already satisfied: click in ./.venv/lib/python3.13/site-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in ./.venv/lib/python3.13/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.13/site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.13/site-packages (from nltk) (4.68.3)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.13/site-packages (from smart_open>=1.8.1->gensim) (2.2.2)
# [nltk_data] Downloading package stopwords to /Users/fahim/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /Users/fahim/nltk_data...
# True

# %% [markdown]
# ## Q1: One-Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

words = [["cat"], ["dog"], ["bird"], ["cat"]]

encoder = OneHotEncoder()

encoded = encoder.fit_transform(words)

print(encoded.toarray())
# Out:
# [[0. 1. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]]

# %% [markdown]
# ## Q2: TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "I love NLP",
    "NLP is amazing",
    "Machine learning is fun"
]

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

print(tfidf_matrix.toarray())
# Out:
# [[0.         0.         0.         0.         0.79596054 0.
#   0.60534851]
#  [0.68091856 0.         0.51785612 0.         0.         0.
#   0.51785612]
#  [0.         0.52863461 0.40204024 0.52863461 0.         0.52863461
#   0.        ]]

# %% [markdown]
# ## Q3: CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

docs = ["apple orange apple","orange banana"]

vectorizer = CountVectorizer()

matrix = vectorizer.fit_transform(docs)

print(matrix.toarray())
# Out:
# [[2 0 1]
#  [0 1 1]]

# %% [markdown]
# ## Q4: Word2Vec

# %%
from gensim.models import Word2Vec

sentences = [
    ["I", "love", "NLP"],
    ["NLP", "is", "awesome"],
    ["Machine", "learning", "is", "fun"]
]

model = Word2Vec(
    sentences,
    vector_size=50,
    window=2,
    min_count=1
)

print(model.wv["NLP"])
# Out:
# [-0.01631583  0.0089916  -0.00827415  0.00164907  0.01699724 -0.00892435
#   0.009035   -0.01357392 -0.00709698  0.01879702 -0.00315531  0.00064274
#  -0.00828126 -0.01536538 -0.00301602  0.00493959 -0.00177605  0.01106732
#  -0.00548595  0.00452013  0.01091159  0.01669191 -0.00290748 -0.01841629
#   0.0087411   0.00114357  0.01488382 -0.00162657 -0.00527683 -0.01750602
#  -0.00171311  0.00565313  0.01080286  0.01410531 -0.01140624  0.00371764
#   0.01217773 -0.0095961  -0.00621452  0.01359526  0.00326295  0.00037983
#   0.00694727  0.00043555  0.01923765  0.01012121 -0.01783478 -0.01408312
#   0.00180291  0.01278507]

# %% [markdown]
# ## Q5: Lowercase

# %%
text = "WELCOME TO NLP"

text = text.lower()

print(text)
# Out:
# welcome to nlp

# %% [markdown]
# ## Q6: Remove Punctuation

# %%
import re

text = "Hello!!! Welcome, to NLP."

clean_text = re.sub(r"[^\w\s]", "", text)

print(clean_text)
# Out:
# Hello Welcome to NLP

# %% [markdown]
# ## Q7: Remove Numbers

# %%
import re

text = "Python3 was released in 2008."

result = re.sub(r"\d+", "", text)

print(result)
# Out:
# Python was released in .

# %% [markdown]
# ## Q8: Extract Email

# %%
import re

text = """
Contact:
student@gmail.com
teacher@yahoo.com
"""

emails = re.findall(r"[\w\.-]+@[\w\.-]+\.\w+", text)

print(emails)
# Out:
# ['student@gmail.com', 'teacher@yahoo.com']

# %% [markdown]
# ## Q9: Remove Extra Spaces

# %%
import re

text = "I      love       NLP"

text = re.sub(r"\s+", " ", text).strip()

print(text)
# Out:
# I love NLP

# %% [markdown]
# ## Q10: Tokenization

# %%
text = "Natural Language Processing"

tokens = text.split()

print(tokens)
# Out:
# ['Natural', 'Language', 'Processing']

# %% [markdown]
# ## Q11: Stopword Removal

# %%
from nltk.corpus import stopwords

words = ["I", "love", "to", "learn", "NLP"]

stop_words = set(stopwords.words("english"))

filtered = [word for word in words if word.lower() not in stop_words]

print(filtered)
# Out:
# ['love', 'learn', 'NLP']

# %% [markdown]
# ## Q12: Stemming

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = ["playing", "played", "plays"]

stems = [stemmer.stem(word) for word in words]

print(stems)
# Out:
# ['play', 'play', 'play']

# %% [markdown]
# ## Q13: Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ["running", "better", "cars"]

lemmas = [lemmatizer.lemmatize(word) for word in words]

print(lemmas)
# Out:
# ['running', 'better', 'car']

# %% [markdown]
# ## Q14: Remove URLs

# %%
import re

text = "Visit https://google.com for more information."

clean = re.sub(r"https?://\S+", "", text)

print(clean.strip())
# Out:
# Visit  for more information.

# %% [markdown]
# ## Q15: Remove HTML

# %%
import re

html = "<h1>Welcome</h1><p>This is NLP.</p>"

clean = re.sub(r"<.*?>", "", html)

print(clean)
# Out:
# WelcomeThis is NLP.

# %% [markdown]
# ## Q16: Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

corpus = [
    "I love NLP",
    "NLP is fun"
]

vectorizer = CountVectorizer()
bow = vectorizer.fit_transform(corpus)

print(bow.toarray())
# Out:
# [[0 0 1 1]
#  [1 1 0 1]]

# %% [markdown]
# ## Q17: Access Word2Vec Vector

# %%
from gensim.models import Word2Vec

sentences = [
    ["cat", "dog", "animal"],
    ["lion", "tiger", "animal"]
]

model = Word2Vec(sentences, vector_size=50, min_count=1)

vector = model.wv["animal"]

print(vector)
# Out:
# [-1.0724545e-03  4.7286271e-04  1.0206699e-02  1.8018546e-02
#  -1.8605899e-02 -1.4233618e-02  1.2917745e-02  1.7945977e-02
#  -1.0030856e-02 -7.5267432e-03  1.4761009e-02 -3.0669428e-03
#  -9.0732267e-03  1.3108104e-02 -9.7203208e-03 -3.6320353e-03
#   5.7531595e-03  1.9837476e-03 -1.6570430e-02 -1.8897636e-02
#   1.4623532e-02  1.0140524e-02  1.3515387e-02  1.5257311e-03
#   1.2701781e-02 -6.8107317e-03 -1.8928028e-03  1.1537147e-02
#  -1.5043275e-02 -7.8722071e-03 -1.5023164e-02 -1.8600845e-03
#   1.9076237e-02 -1.4638334e-02 -4.6675373e-03 -3.8754821e-03
#   1.6154874e-02 -1.1861792e-02  9.0324880e-05 -9.5074680e-03
#  -1.9207101e-02  1.0014586e-02 -1.7519170e-02 -8.7836506e-03
#  -7.0199967e-05 -5.9236289e-04 -1.5322480e-02  1.9229487e-02
#   9.9641159e-03  1.8466286e-02]

# %% [markdown]
# ## Q18: Regex Phone

# %%
import re

text = "Call me at +8801712345678"

phone = re.findall(
    r"\+\d{13}",
    text
)

print(phone)
# Out:
# ['+8801712345678']

# %% [markdown]
# ## Q19: Remove Special Characters

# %%
import re

text = "Hello@#$%^World!"

clean = re.sub(
    r"[^A-Za-z0-9\s]",
    "",
    text
)

print(clean)

# %% [markdown]
# ## Q20: Complete NLP Preprocessing

# %%
import re

text = "Hello!!! Visit https://abc.com Email: student@gmail.com 123"

text = text.lower()

text = re.sub(r"https?://\S+", "", text)
text = re.sub(r"\S+@\S+", "", text)
text = re.sub(r"\d+", "", text)
text = re.sub(r"[^\w\s]", "", text)
text = re.sub(r"\s+", " ", text).strip()

print(text)
# Out:
# hello visit email

# %% [markdown]
# #Q: Optional :
#
# **Word2Vec**
#
# Explain the difference between **CBOW (Continuous Bag of Words)** and **Skip-Gram** architectures.
#
# Your answer should include:
# 1. How each model predicts words.
# 2. Which model performs better on small datasets.
# 3. Which model is better for learning rare words.
# 4. One practical advantage of Word2Vec over One-Hot Encoding.
