# %% [markdown]
# # DL Final Exam
#
# **Name:** Fahim Montasir
#
# **Course Email:** fahimmontasirshakil@gmail.com
#
#
# ## End of Assignment
#
# Before submitting:
# - Run all cells from top to bottom.
# - Check that all answer sections are filled.
# - Instruction video অনুযায়ী আমাদের দেয়া Colab ফাইলটি থেকে প্রথম একটি Save copy in drive করে নিবা। এরপর Google colab এর মধ্যে কোডগুলো করবে এবং সেই ফাইলটি ‘Anyone with the link’ & ‘View’ Access দিয়ে ফাইলটির Shareble Link টি সাবমিট করবে।

# %% [markdown]
# # Question 01: [ Marks 10 ]
#
# ## Explain the concept of backpropagation in detail. Describe how the error is propagated from the output layer to the hidden layers. Derive the mathematical expressions for weight updates using the chain rule, and explain how learning rate affects the training process.

# %% [markdown]
# # Write Answer 01:
#
# Backpropagation is how a neural network learns from mistakes.
#
# 1. Forward pass: Input moves through layers and gives a prediction called y_hat.
# 2. Loss: We measure error. Example in python style: loss = 0.5 * (y_hat - y)**2
# 3. Backward pass: This error is sent from output layer back to hidden layers.
#
# Using chain rule in simple python style:
# - output_error = (y_hat - y) * f_prime(z_out)
# - hidden_error = (W_out.T @ output_error) * f_prime(z_hidden)
#
# Gradients and updates:
# - dL_dW = delta @ a_prev.T
# - W_new = W_old - lr * dL_dW
# - b_new = b_old - lr * dL_db
#
# Here lr means learning rate.
# - Small lr: learning is slow but stable.
# - Large lr: learning is fast but may overshoot and not converge.

# %% [markdown]
# # Question 02: [ Marks 10 ]
#
# ## Consider a neural network with one hidden layer using sigmoid activation. Derive the complete backpropagation equations for updating weights and biases. Show all steps clearly, including forward pass, loss calculation, and backward pass.

# %% [markdown]
# ## Write Answer 02:
#
# Let input be x, hidden weights W1 and b1, output weights W2 and b2.
# Sigmoid in python style: sigmoid(z) = 1 / (1 + exp(-z))
#
# Forward pass:
# - z1 = W1 @ x + b1
# - a1 = sigmoid(z1)
# - z2 = W2 @ a1 + b2
# - y_hat = sigmoid(z2)
#
# Loss (MSE):
# - loss = 0.5 * (y_hat - y)**2
#
# Backward pass:
# - delta2 = (y_hat - y) * y_hat * (1 - y_hat)
# - dW2 = delta2 @ a1.T
# - db2 = delta2
#
# - delta1 = (W2.T @ delta2) * a1 * (1 - a1)
# - dW1 = delta1 @ x.T
# - db1 = delta1
#
# Update rules:
# - W2 = W2 - lr * dW2
# - b2 = b2 - lr * db2
# - W1 = W1 - lr * dW1
# - b1 = b1 - lr * db1

# %% [markdown]
# # Question 03: [Marks 5]
#
# ## Discuss the vanishing gradient problems in deep neural networks. Explain why they occur during backpropagation, how activation functions contribute to this issue, and suggest at least three techniques to overcome these problems.

# %% [markdown]
# ## Write Answer 03:
#
# Vanishing gradient means gradients become very small in deep networks.
# When backpropagation moves through many layers, small derivatives are multiplied many times. Then early layers get almost zero update.
#
# Why it happens:
# - Sigmoid and tanh have derivatives less than 1 in many regions.
# - Deep networks multiply these small values repeatedly.
#
# Problems:
# - Very slow learning in early layers.
# - Model cannot capture deep patterns well.
#
# Ways to solve it (at least 3):
# 1. Use **ReLU** or variants (Leaky ReLU, ELU).
# 2. Use **proper initialization** (He/Xavier).
# 3. Use **Batch Normalization**.
# 4. Use **Residual connections** (ResNet skip links).
# 5. Use **gradient clipping** when needed.

# %% [markdown]
# # Question 04: [ Marks 5 ]
#
# ## Describe the architecture of an Artificial Neural Network (ANN) in detail. Explain the role of each component (neurons, weights, bias, activation functions). Also discuss how increasing the number of hidden layers and neurons affects model performance and overfitting.

# %% [markdown]
# ## Write Answer 04:
#
# An ANN has layers of neurons: input layer, hidden layer(s), and output layer.
#
# Main parts:
# - Neuron: basic computing unit.
# - Weights (W): control importance of inputs.
# - Bias (b): shifts activation, helps flexible fitting.
# - Activation function: adds non-linearity (ReLU, sigmoid, tanh).
#
# How data flows:
# - Each neuron does: z = W * x + b
# - Then activation is applied: a = f(z)
#
# Effect of more layers/neurons:
# - Can learn more complex patterns.
# - But too many can cause overfitting (good on train, bad on test).
# - Training also becomes slower and needs more data.
#
# To reduce overfitting: dropout, regularization, early stopping, and good validation.

# %% [markdown]
# # Question 05: [ Marks 10 ]
#
# ## Compare Artificial Neural Networks (ANN) and Convolutional Neural Networks (CNN) in detail. Discuss their architectures, working principles, advantages, limitations, and typical use cases such as image processing, tabular data, and pattern recognition.

# %% [markdown]
# ## Write Answer 05:
#
# ### ANN vs CNN (Simple Comparison)
#
# - **Architecture**
#   - ANN: Fully connected layers.
#   - CNN: Convolution + pooling + fully connected layers.
#
# - **How they work**
#   - ANN: Treats all inputs equally, usually flatten input.
#   - CNN: Uses filters to detect local patterns (edges, textures, shapes).
#
# - **Parameters**
#   - ANN: Many parameters for images, can be heavy.
#   - CNN: Fewer parameters due to shared filters.
#
# - **Strengths**
#   - ANN: Good for tabular/numeric data.
#   - CNN: Excellent for images, videos, spatial patterns.
#
# - **Limitations**
#   - ANN: Not efficient for image structure.
#   - CNN: More complex and needs more compute for large models.
#
# - **Use cases**
#   - ANN: house price prediction, fraud detection, tabular classification.
#   - CNN: image classification, face detection, medical image analysis, pattern recognition.

# %% [markdown]
# # Question 06: [ Marks 10 ]
#
# ## Explain different activation functions used in neural networks, including Sigmoid, Tanh, and ReLU. Provide their mathematical formulas, advantages, disadvantages, and suitable use cases. Also discuss why ReLU is widely used in deep learning.

# %% [markdown]
# ## Write Answer 06:
#
# ### 1) Sigmoid
# - Python style: sigmoid(x) = 1 / (1 + exp(-x))
# - Range: 0 to 1
# - Pros: good for probability output.
# - Cons: vanishing gradient, not zero-centered, slower learning.
# - Use: output layer in binary classification.
#
# ### 2) Tanh
# - Python style: tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))
# - Range: -1 to 1
# - Pros: zero-centered, often better than sigmoid in hidden layers.
# - Cons: still has vanishing gradient for large absolute x.
# - Use: some RNN/hidden layer settings.
#
# ### 3) ReLU
# - Python style: relu(x) = max(0, x)
# - Range: 0 to infinity
# - Pros: simple, fast, reduces vanishing gradient, sparse activations.
# - Cons: dead ReLU problem (neurons can get stuck at 0).
# - Use: most hidden layers in deep learning.
#
# Why ReLU is widely used:
# It trains faster, is easy to compute, and works well in deep networks.

# %% [markdown]
# # Question 07: [ Marks 10 ]
#
# ## Describe the convolution operation in CNNs in detail. Explain how filters (kernels) work, how feature maps are generated, and how parameters like stride and padding affect the output. Provide a step-by-step example using a small input matrix.
# Note :  You've to attach an image here.

# %% [markdown]
# ## Write Answer 07:
#
# Convolution means sliding a small filter (kernel) over the input and computing weighted sums.
# Each position gives one value. All values together make a feature map.
#
# Output size formula in python style:
# - H_out = floor((H + 2*P - K) / S) + 1
# - W_out = floor((W + 2*P - K) / S) + 1
# where K = kernel size, S = stride, P = padding.
#
# Small example
# - input_matrix = [[1,2,3],[4,5,6],[7,8,9]]
# - kernel = [[1,0],[0,1]]
# - stride = 1, padding = 0
#
# Step by step output values:
# - top_left = 1*1 + 2*0 + 4*0 + 5*1 = 6
# - top_right = 2*1 + 3*0 + 5*0 + 6*1 = 8
# - bottom_left = 4*1 + 5*0 + 7*0 + 8*1 = 12
# - bottom_right = 5*1 + 6*0 + 8*0 + 9*1 = 14
#
# feature_map = [[6,8],[12,14]]
#
# Image note: Attach a small diagram showing input, kernel sliding, and output map below this answer.

# %% [markdown]
# # Question 08: [ Marks 10 ]
#
# ## Explain the concept of pooling in CNNs. Compare MaxPooling and AveragePooling in terms of operation, advantages, and impact on feature extraction. Discuss how pooling helps in reducing overfitting and computational complexity.

# %% [markdown]
# Write Answer 08:
#
# Pooling reduces spatial size of feature maps.
# It keeps important information and removes some details.
#
# ### MaxPooling vs AveragePooling
# - **MaxPooling:** takes the maximum value in each window.
#   - Keeps strongest features (edges, key patterns).
# - **AveragePooling:** takes the average value in each window.
#   - Keeps smooth/general information.
#
# ### Advantages
# - Reduces feature map size → fewer computations.
# - Helps reduce overfitting.
# - Gives small translation tolerance (small shifts in image).
#
# In practice, MaxPooling is used more often in CNNs because strong features are usually more useful for recognition.

# %% [markdown]
# # Question 09: [ Marks 10 ]
#
# ## Given an input image of size 128×128×3, explain step-by-step how the dimensions change after multiple convolution and pooling layers. Clearly show calculations for output size after each layer using appropriate formulas.

# %% [markdown]
# # Write Answer 09:
#
# Input image: 128 x 128 x 3
#
# Use output formula in python style:
# - H_out = floor((H + 2*P - K) / S) + 1
# - W_out = floor((W + 2*P - K) / S) + 1
#
# Assume this sequence:
# 1. Conv(3x3, stride=1, padding=1, filters=32)
# 2. MaxPool(2x2, stride=2)
# 3. Conv(3x3, stride=1, padding=1, filters=64)
# 4. MaxPool(2x2, stride=2)
# 5. Conv(3x3, stride=1, padding=1, filters=128)
# 6. MaxPool(2x2, stride=2)
#
# Step-by-step size:
# - Start: 128 x 128 x 3
# - After Conv1: 128 x 128 x 32 (same height and width)
# - After Pool1: 64 x 64 x 32
# - After Conv2: 64 x 64 x 64
# - After Pool2: 32 x 32 x 64
# - After Conv3: 32 x 32 x 128
# - After Pool3: 16 x 16 x 128
#
# Flatten for dense layer:
# - features = 16 * 16 * 128 = 32768

# %% [markdown]
# # Question 10: [ Marks 20 ]
#
# ## Design and implement a deep Convolutional Neural Network (CNN) for a multi-class image classification problem using PyTorch. The network should consist of four convolutional blocks, where each block includes two convolution layers followed by activation and normalization, and a pooling layer at the end. The number of filters should increase progressively across blocks. After the convolutional part, flatten the feature maps and connect them to fully connected layers with dropout for regularization, and produce final outputs corresponding to K classes. Also explain the role of each part of the network in detail.

# %% [markdown]
# # Write Answer 10:
#
# Below is a simple PyTorch CNN with 4 convolution blocks.
# Each block has 2 conv layers + ReLU + BatchNorm, then MaxPool.
#
# ```python
# import torch
# import torch.nn as nn
#
# class DeepCNN(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.features = nn.Sequential(
#             # Block 1: 3 -> 32
#             nn.Conv2d(3, 32, 3, padding=1), nn.BatchNorm2d(32), nn.ReLU(),
#             nn.Conv2d(32, 32, 3, padding=1), nn.BatchNorm2d(32), nn.ReLU(),
#             nn.MaxPool2d(2),
#
#             # Block 2: 32 -> 64
#             nn.Conv2d(32, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(),
#             nn.Conv2d(64, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(),
#             nn.MaxPool2d(2),
#
#             # Block 3: 64 -> 128
#             nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(),
#             nn.Conv2d(128, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(),
#             nn.MaxPool2d(2),
#
#             # Block 4: 128 -> 256
#             nn.Conv2d(128, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(),
#             nn.Conv2d(256, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(),
#             nn.MaxPool2d(2),
#         )
#         self.classifier = nn.Sequential(
#             nn.Flatten(),
#             nn.Linear(256*8*8, 512),  # for input image 128x128
#             nn.ReLU(),
#             nn.Dropout(0.5),
#             nn.Linear(512, num_classes)
#         )
#
#     def forward(self, x):
#         x = self.features(x)
#         x = self.classifier(x)
#         return x
# ```
#
# ### Role of each part
# - **Conv layers:** learn local patterns (edges, textures, shapes).
# - **ReLU:** adds non-linearity and helps deep training.
# - **BatchNorm:** stabilizes training and speeds up learning.
# - **MaxPool:** reduces size and computation.
# - **Flatten + FC layers:** combine extracted features for final decision.
# - **Dropout:** reduces overfitting.
# - **Final layer (K outputs):** gives class scores for K classes.
